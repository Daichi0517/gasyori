# %% [markdown]
# <a href="https://colab.research.google.com/github/Daichi0517/gasyori/blob/main/FILES/kireinisuru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np
#画像の読み取り
img_dark = cv2.imread('imori_dark.jpg')
#グレイスケール
gray_img = cv2.cvtColor(img_dark,cv2.COLOR_BGR2GRAY)

clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
cl1 = clahe.apply(gray_img)
cv2_imshow(cl1)
"""# ヒストグラムを出力
plt.hist(gray_img.ravel(),bins=255,rwidth=0.8,range=(0,255))"""
# Out:
# <PIL.Image.Image image mode=L size=128x128>
# '# ヒストグラムを出力\nplt.hist(gray_img.ravel(),bins=255,rwidth=0.8,range=(0,255))'
