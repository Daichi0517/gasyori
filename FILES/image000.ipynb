# %% [markdown]
# <a href="https://colab.research.google.com/github/Daichi0517/gasyori/blob/main/FILES/image000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as plt
import cv2
from google.colab.patches import cv2_imshow

#画像の読み込み
img = cv2.imread('imori.jpg')
img_noise = cv2.imread('imori_noise.jpg')
#画像の表示
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
