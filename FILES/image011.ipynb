# %% [markdown]
# <a href="https://colab.research.google.com/github/Daichi0517/gasyori/blob/main/FILES/image011.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as plt
import cv2
from google.colab.patches import cv2_imshow

#画像の読み込み
img = cv2.imread('imori.jpg')
img_noise = cv2.imread('imori_noise.jpg')
#フィルターのカーネル
kernel = np.ones((3,3),np.float32)/9
#平滑化フィルタ
img11 = cv2.filter2D(img,-1,kernel)
#画像の表示
cv2_imshow(img11)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
