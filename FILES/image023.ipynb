# %% [markdown]
# <a href="https://colab.research.google.com/github/Daichi0517/gasyori/blob/main/FILES/image023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import numpy as np
#画像の読み取り
img = cv2.imread('imori.jpg')
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,img_otsu = cv2.threshold(img_gray,0,255,cv2.THRESH_OTSU)
def gamma(img,c=1,g=2.2):
   #画像の高さ、幅、色を取得
   h,w,c = img.shape
   s = h*w*c*1.
   #コピー
   out=img.copy().astype(np.float32)
   out /= 255.
   #ガンマ補正
   out = (1/c*out)**(1/g)

   out *= 255
   out = out.astype(np.uint8)
   return out

out = gamma(img)
out_gray = cv2.cvtColor(out,cv2.COLOR_BGR2GRAY)
ret,out_otsu = cv2.threshold(out_gray,0,255,cv2.THRESH_OTSU)
#画像の表示
cv2_imshow(out)
# ヒストグラムを出力
plt.hist(out.ravel(),bins=255,rwidth=0.8,range=(0,255));  # ; をつけることで返り値の表示をなくすことができる
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
