# %% [markdown]
# <a href="https://colab.research.google.com/github/Daichi0517/gasyori/blob/main/FILES/image013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# 画像の読み込み
img = cv2.imread('imori.jpg')
# 処理
def processing(img):
    img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    H, W = img.shape

    # ゼロパディング
    pad = 3 // 2
    out = np.zeros((H + pad * 2, W + pad * 2,), dtype=float)
    out[pad:pad + H, pad:pad + W] = img.copy().astype(float)
    tmp = out.copy()
    # フィルタリング
    for h in range(H):
        for w in range(W):
          out[pad + h, pad + w] = np.max(tmp[h:h + 3, w:w + 3])-np.min(tmp[h:h+3,w:w+3])
    out = out[pad:pad + H, pad:pad + W].astype(np.uint8)
    return out
img13 = processing(img)
# 画像の表示
cv2_imshow(img13)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=128x128>
